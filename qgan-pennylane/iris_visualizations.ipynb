# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import colors
from matplotlib.ticker import PercentFormatter
import qiskit 
from qiskit.visualization import *

# %%
fake_samples = [

[0.017175734, 0.5342689, 1.0, 0.27575058],
[0.13964686, 1.0, 0.5668607, 0.0028959648],
[0.03616139, 1.0, 0.14550029, 0.004756863],
[0.0067900666, 1.0, 0.5169593, 0.6223371],
[0.08930219, 0.52627516, 1.0, 0.05515871],
[0.015575302, 1.0, 0.02323413, 8.284619e-05],
[0.045446754, 1.0, 0.3096018, 0.35226312],
[0.0006699597, 1.0, 0.004793469, 0.0035181919]

]

probs = []
for sample in fake_samples:
    cts = {}
    for i,j in enumerate(sample):
        cts[str(i)] = j
    probs.append(cts)

# %%
plot_histogram([probs[i] for i in range(len(probs))])

# %%
fake_samples = [

[0.24887292, 0.5618089, 0.12045609, 0.7796944],
[0.40483087, 0.7648634, 0.35666695, 0.35197255],
[0.38152486, 0.87545705, 0.057106182, 0.2911231],
[0.1874248, 0.14029239, 0.014253616, 0.9721043],
[0.3174785, 0.4785407, 0.37922147, 0.7255324],
[0.33884668, 0.92389154, 0.0032073911, 0.17775555],
[0.3705406, 0.8165377, 0.015631558, 0.44240427],
[0.3298669, 0.9410326, 0.002673067, 0.075089],

]

probs = []
for sample in fake_samples:
    cts = {}
    for i,j in enumerate(sample):
        cts[str(i)] = j
    probs.append(cts)

plot_histogram([probs[i] for i in range(len(probs))])
